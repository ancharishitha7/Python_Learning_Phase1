# %%
#phase-1
#basic python
print("                     A SIMPLE CALCULATOR                                 ")
print("1.Addition\n2.Subtraction\n3.Multiplication\n4.Division\n5.Modulo Division\n6.Exponential")
operator=int(input("Enter Number"))
num1=int(input("enter first number"))
num2=int(input("enter second number:"))
#for addition
if operator==1:
    print("performing addition")
    addition=num1+num2
    print("Additon:%2d"%(addition))
    print()
    operator=int(input("enter number:"))
    num1=int(input("enter first number"))
    num2=int(input("enter second number:"))
#subtraction
if operator==2:
    print("performing subtraction")
    sub=num1-num2
    print("Subtraction:%2d"%(sub))
    print()
    operator=int(input("enter number:"))
    num1=int(input("enter first number"))
    num2=int(input("enter second number:"))
    #multiplication
if operator==3:
    print("performing multiplication")
    mul=num1*num2
    print("Multiplication:%2d"%(mul))
    print()
    operator=int(input("enter number:"))
    num1=int(input("enter first number"))
    num2=int(input("enter second number:"))
    #division
if operator == 4:
    print("Performing integer division")
    div = num1 // num2  # integer division
    print("Division: %d" % div)
    print()
    operator=int(input("enter number:"))
    num1=int(input("enter first number"))
    num2=int(input("enter second number:"))
    #modulo division
if operator==5:
    print("performing modulo division")
    mod=num1%num2
    print("Modulos:%2d"%(mod))
    print()
    operator=int(input("enter number:"))
    num1=int(input("enter first number"))
    num2=int(input("enter second number:"))
    #exponential's 
if operator==6:
    print("performing Exponential")
    exp=num1**num2
    print("Exponent:%2d"%(exp))
    print()
    operator=int(input("enter number:"))
    num1=int(input("enter first number"))
    num2=int(input("enter second number:"))
else:
    print("error occurs!!!!")
    print("please enter valid number")
# Out:
#                      A SIMPLE CALCULATOR
# 1.Addition
# 2.Subtraction
# 3.Multiplication
# 4.Division
# 5.Modulo Division
# 6.Exponential
# Enter Number 1
# enter first number 1
# enter second number: 2
# performing addition
# Additon: 3
# enter number: 2
# enter first number 2
# enter second number: 3
# performing subtraction
# Subtraction:-1
# enter number: 3
# enter first number 3
# enter second number: 4
# performing multiplication
# Multiplication:12
# enter number: 4
# enter first number 4
# enter second number: 5
# Performing integer division
# Division: 0
# enter number: 5
# enter first number 5
# enter second number: 6
# performing modulo division
# Modulos: 5

# %% [markdown]
# #

# %%
# python function
# guess the number game
n=int(input("enter number between 1 and 100:"))
guess_number=int(input("Guess the number:"))
def number_game(n,guess_number):
    if guess_number>n:
        return "TOO HIGH.PLEASE TRY AGAIN"
        guess_number=int(input("Guess the number:"))
    elif guess_number<n:
        return "TOO LOW!!!PLEASE TRY AGAIN LATER"
        guess_number=int(input("Guess the number:"))
    else:
        return guess_number
        return "YAHOOOO! YOU WON"
output=number_game(56,23)
print(output)
